# %% [markdown]
# # Vector Operations

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set()

# %% [markdown]
# ## Plotting Vector

# %%
plt.quiver(0,0,4,5)
plt.show()

# %% [markdown]
# ## Sample Vector Plot

# %%
plt.quiver(0,0,4,5, scale_units = 'xy',angles ="xy", scale = 1)
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# ## Vector Addition

# %%
vector_1 = np.asarray([0,0,2,3])
vector_2 = np.asarray([0,0,3,-2])
outcome = vector_1 + vector_2
print(outcome)
# Out:
# [0 0 5 1]

# %%
plt.quiver(0,0,2,3, scale_units = 'xy',angles ="xy", scale = 1, color='b')
plt.quiver(0,0,3,-2, scale_units = 'xy',angles ="xy", scale = 1, color='y')
plt.quiver(0,0,5,1, scale_units = 'xy',angles ="xy", scale = 1, color='r')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# ## Vector Subtraction

# %%
vector_1 = np.asarray([0,0,2,3])
vector_2 = np.asarray([0,0,3,-2])
total = vector_1 - vector_2
print(total)
# Out:
# [ 0  0 -1  5]

# %%
plt.quiver(0,0,2,3, scale_units = 'xy',angles ="xy", scale = 1, color='b')
plt.quiver(0,0,3,-2, scale_units = 'xy',angles ="xy", scale = 1, color='y')
plt.quiver(0,0,-1,5, scale_units = 'xy',angles ="xy", scale = 1, color='r')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# ## Vector Multiplication

# %%
vector_1 = np.asarray([0,0,2,3])
total = 2 * vector_1
print(total)
# Out:
# [0 0 4 6]

# %%
plt.quiver(0,0,2,3, scale_units = 'xy',angles ="xy", scale = 1, color='b')
plt.quiver(0,0,4,6, scale_units = 'xy',angles ="xy", scale = 1, color='y')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()

# %% [markdown]
# ## Vector Multiplication use Negative values

# %%
vector_1 = np.asarray([0,0,2,3])
total = -0.5 * vector_1
print(total)
# Out:
# [-0.  -0.  -1.  -1.5]

# %%
plt.quiver(0,0,2,3, scale_units = 'xy',angles ="xy", scale = 1, color='b')
plt.quiver(0,0,-1,-1.5, scale_units = 'xy',angles ="xy", scale = 1, color='y')
plt.xlim(-8,8)
plt.ylim(-8,8)
plt.show()
